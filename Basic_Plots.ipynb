# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Types of Plots

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
url = 'http://bit.ly/2b72LNj'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(x = 'wt', y = 'mpg', data = df)
pass

# %% [markdown]
# ## Line plot

# %%
plt.plot('wt', 'mpg', '-o', data = df.sort_values('wt'))
pass

# %% [markdown]
# ## Fitting a regression line

# %% [markdown]
# ### Linear regression

# %%
sns.regplot('wt', 'mpg', data = df)
pass

# %% [markdown]
# ### Non-parametric regression

# %%
sns.regplot('wt', 'mpg', data = df, lowess = True,)
pass

# %% [markdown]
# ## Swarm plot

# %%
sns.swarmplot('gear', 'mpg', data = df)
pass

# %% [markdown]
# ## Bar plot

# %%
sns.barplot('gear', 'mpg', data = df)
pass

# %% [markdown]
# ## Box plot

# %%
sns.boxplot('gear', 'mpg', data = df)
pass

# %% [markdown]
# ## Violin plot

# %%
sns.violinplot('gear', 'mpg', data = df)
pass

# %% [markdown]
# ## Histogram

# %%
sns.distplot(df.mpg, kde=False, rug=True)
pass

# %% [markdown]
# ## Density plot

# %%
sns.distplot(df.mpg)
pass

# %% [markdown]
# ## Heatmap

# %%
import string

# %%
nrows = 20
ncols = 20
row_names = range(1970, 1970 + nrows)
col_names = [string.ascii_lowercase[i:i+5] for i in range(ncols)]
values = np.random.random((nrows, ncols))

# %%
df = pd.DataFrame(values, index = row_names, columns = col_names)

# %%
sns.heatmap(df)
pass

# %%
cmap = sns.light_palette('red', as_cmap=True)
g = sns.clustermap(df, cmap = cmap)
plt.setp(g.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
pass

# %% [markdown]
# ## Exercises
#
# For these exercises, we will see how to visulaize data on HIV subjects in the UNC database.

# %%
subjects = pd.read_excel('data/capstone1/HIV Boot Camp.xls', sheetname='Patient Information')

# %%
subjects.head()
# Out:
#    ID  AGE   RACE SEX MSM  IDU  UNC Entry to Care Year  \
# 0   1   38  AMIND   F  No   No                    2012
# 1   2   44  AMIND   F  No   No                    2006
# 2   3   33  AMIND   F  No   No                    2005
# 3   4   60  AMIND   F  No  Yes                    2003
# 4   6   47  AMIND   F  No   No                    2001
#
#   Prior HIV Care Elsewhere On ART   ART Type
# 0                       NO    Yes  Integrase
# 1                      YES     No        NaN
# 2                       NO     No        NaN
# 3                       NO    Yes  Integrase
# 4                      YES    Yes      Other

# %% [markdown]
# **1**. Make a linear regression plot of `AGE` on the y-axis by `UNC Entry to Care Year` on the x-axis. Is there any trend over time that you can observe?

# %% [markdown]
# **2**. Chcek the help documentaion for `sns.countplot`. Then create a barchart of the count of the number of people by SEX.

# %% [markdown]
# **3**. Make a horizontal stacked barchart of the count of the number of people by RACE and color by SEX. As before, look up help on `sns.countplot` to do so.

# %% [markdown]
# **4**. Make a barchart of the AGE of people by RACE.

# %% [markdown]
# **5**. Make a barchart of the AGE of people by RACE, but arrange in order of increasing average age. To do so, you need to give the order argument a list of strings containing the sequnce of RACE desired.

# %% [markdown]
# **6**. (More challenging) Repeat **5**, but get the list of strings using `pandas` rather than manually.

# %% [markdown]
# **7**. Make a swarm plot of the AGE by RACE but only for subejcts who have MSM status equal to 'Yes'.

# %% [markdown]
# **8**. (Challenging) Make a heat map of the mean AGE where the rows correspond to RACe and the columns to 'UNC Entry to Care Year'.
#
# Hint: Look up the `pivot_table` method of `pandas` DataFrames.

# %%
data = subjects.pivot_table(index='RACE', columns='UNC Entry to Care Year', values='AGE')
